# %% [markdown]
# # Patreon - What is Sam Harris Making?
#
# We need to use `Selenium` to do the scraping. Just remember that you also need the `chromedriver` to be able to do live broswer scarping.

# %%
import qgrid
import numpy as np
import pymc3 as pm
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as graph
from IPython.display import display, Markdown
from tqdm import tqdm
from selenium import webdriver

graph.style.use('fivethirtyeight')

# %%
# Open Chrome
broswer = webdriver.Chrome()

# %%
# Go to website
broswer.get('https://graphtreon.com/all-patreon-creators')
# broswer.implicitly_wait(10)  # Units are seconds

# %%
# Create Empty Dataframe
scraped = []

# %%
rows = broswer.find_elements_by_css_selector('tr')

print('N Rows:', len(rows))

for row in tqdm(rows, desc='Scraping'):
    cols = row.find_elements_by_css_selector('td')
    scraped.append([col.text for col in cols])
# Out:
# Scraping:   2%|▏         | 2/101 [00:00<00:09, 10.74it/s]
# N Rows: 101
# Scraping: 100%|██████████| 101/101 [00:17<00:00,  5.47it/s]

# %%
scraped = scraped[1:]
df = pd.DataFrame(scraped)
df.head()
# Out:
#    0                                                  1       2  \
# 0  1  Philip DeFranco is creating a News and Enterta...  13,353
# 1  2  Chapo Trap House is creating Chapo Trap House ...  12,975
# 2  3       Amanda Palmer is creating Art (amandapalmer)   9,416
# 3  4  Sam Harris is creating The Waking Up Podcast (...   8,390
# 4  5    Team Cemu is creating emulation software (cemu)   8,011
#
#                       3                4    5         6
# 0                                           5  Apr 2017
# 1  $57,831.80 per month  $4.46 per month  348  May 2016
# 2  $36,410.40 per thing  $3.87 per thing  795  Mar 2015
# 3                                         445  Feb 2016
# 4  $34,273.30 per month  $4.28 per month  458  Feb 2016

# %%
# Clean Data Functions
def find_months(thing):
    if thing is None:
        return pd.np.nan
    elif 'month' in thing:
        return pd.np.nan
    else:
        return 1
    
# Clean Data
df['contribs'] = df[2].apply(lambda r: pd.np.NaN if r is None else r.replace(',', ''))
df['contribs'] = df['contribs'].astype(float)
df['dropme'] = df[3].apply(lambda x: find_months(x))
df['ppv'] = df[3].apply(lambda x: pd.np.nan if x is None else x.split(' ')[0])
df['ppv'] = df['ppv'].apply(lambda x: pd.np.nan if x is None or type(x) is float else x.replace(',', ''))
df['ppv'] = df['ppv'].apply(lambda x: pd.np.nan if x is None or type(x) is float else x.replace('$', ''))
df['ppv'] = df['ppv'].apply(lambda x: pd.np.nan if x == '' else x)
df['ppv'] = df['ppv'].astype(float)

data = df.dropna().drop('dropme', axis='columns')
print('N =', len(data))
display(data.head())
# Out:
# N = 172
#      0                                                  1      2  \
# 2    3       Amanda Palmer is creating Art (amandapalmer)  9,416
# 9   10      CGP Grey is creating Youtube videos (cgpgrey)  7,203
# 27  28  Every Frame a Painting is creating Video Essay...  4,309
# 37  38   Pentatonix is creating Music Videos (pentatonix)  3,793
# 38  39      Home Free is creating music videos (homefree)  3,766
#
#                              3                      4     5         6  \
# 2         $36,410.40 per thing        $3.87 per thing   795  Mar 2015
# 9         $18,475.30 per Video        $2.56 per Video  1029  Jul 2014
# 27         $7,669.19 per video        $1.78 per video   976  Sep 2014
# 37  $19,377.70 per Music Video  $5.11 per Music Video  1168  Feb 2014
# 38        $26,807.20 per video        $7.12 per video  1061  Jun 2014
#
#     contribs       ppv
# 2     9416.0  36410.40
# 9     7203.0  18475.30
# 27    4309.0   7669.19
# 37    3793.0  19377.70
# 38    3766.0  26807.20

# %% [markdown]
# # The Data
#
# Started with 1000 dropped down to 172 after SUPER quick, dirty and heavy filtering.

# %%
data.to_csv('data/filteredTop1000Patreons.csv')

# %%
data = pd.read_csv('data/filteredTop1000Patreons.csv')

# %%
graph.plot(data['contribs'], data['ppv'], 'o', alpha=0.5)
graph.show()

# %% [markdown]
# Definitely going to fail heteroskedasticity...

# %%
with pm.Model() as model:
    pm.glm.glm('ppv ~ contribs', data, family=pm.glm.families.StudentT())
    trace = pm.sample(3000, pm.NUTS(scaling=pm.find_MAP()), progressbar=True)
# Out:
# WARNING (theano.tensor.blas): We did not found a dynamic library into the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# Optimization terminated successfully.
#          Current function value: 1568.433734
#          Iterations: 31
#          Function evaluations: 37
#          Gradient evaluations: 37
# 100%|██████████| 3000/3000 [00:06<00:00, 430.13it/s]

# %%
pm.traceplot(trace)
graph.show()

# %%
pm.plot_posterior(trace[1000:])
graph.show()

graph.plot(data['contribs'], data['ppv'], 'o', alpha=0.66)
graph.plot(data['contribs'], data['contribs'] * trace['contribs'][1000:].mean() + trace['Intercept'][1000:].mean())
graph.xlabel('Contributors')
graph.ylabel('Payment Per Post')
graph.show()

# %% [markdown]
# To deal with the obvious heteroskedasticity wikipedia recommends using a Cauchy distribution. https://en.wikipedia.org/wiki/Heteroscedasticity

# %%
# Dealing with heteroskedasticity
with pm.Model() as hetero_model:
    # Priors
    m = pm.Normal('m', mu=0, sd=20)
    b = pm.Normal('b', mu=0, sd=500)
    noise = pm.HalfNormal('noise', sd=500)
    
    # Likelihood
    obs = pm.Cauchy('y', alpha=m * data['contribs'] + b, beta=noise, observed=data['ppv'])
    
    # Infer
    trace_cauchy = pm.sample(50000, step=pm.NUTS(), start=pm.find_MAP(), progressbar=True)
# Out:
# Optimization terminated successfully.
#          Current function value: 1535.244028
#          Iterations: 32
# 100%|██████████| 50000/50000 [00:54<00:00, 920.35it/s]
#          Function evaluations: 34
#          Gradient evaluations: 34

# %%
pm.traceplot(trace_cauchy)
graph.show()

pm.plot_posterior(trace_cauchy[1000::2])
graph.show()

# %% [markdown]
# I don't know if I should be amazed the Cauchy distribution for the residuals got the same results as a Student T distribution.

# %%
final_trace = trace_cauchy[1000::2]

graph.plot(data['contribs'], data['ppv'], 'o', alpha=0.66)
graph.plot(data['contribs'], final_trace['m'].mean() * data['contribs'] + final_trace['b'].mean())
graph.xlabel('Contributors')
graph.ylabel('Payment Per Post')
graph.show()

# %% [markdown]
# # Finally The Answer To The Question
#
# How is Sam Harris making from his goddamn podcast on patreon!?

# %%
df_trace = pm.trace_to_dataframe(final_trace)
display(df_trace.head())
# Out:
#           m           b       noise
# 0  2.569761   51.058399  498.965039
# 1  2.551277 -124.653653  525.976539
# 2  2.388243  174.278094  628.974282
# 3  2.134794  324.664617  616.355232
# 4  2.135600  292.950505  675.821447

# %%
# Query point for Sam Harris is 8416 Patreon contributors
df_trace['sam_hat'] = df_trace['m'] * 8416 + df_trace['b'] + df_trace['noise'].apply(
    lambda x: np.random.normal(0, x, size=1)[0]
)
display(df_trace.head())
# Out:
#           m           b       noise       sam_hat
# 0  2.569761   51.058399  498.965039  21352.123161
# 1  2.551277 -124.653653  525.976539  21825.440943
# 2  2.388243  174.278094  628.974282  19759.810255
# 3  2.134794  324.664617  616.355232  18733.795479
# 4  2.135600  292.950505  675.821447  18615.744473

# %%
graph.hist(df_trace['sam_hat'], bins=50)
graph.xlabel('Estimated Earnings Per Podcast ($)')
graph.show()

display(df_trace.describe())

credible_region = df_trace['sam_hat'].quantile(q=[0.05, 0.95]).values
print(credible_region)

display(Markdown('### 95% Chance Sam Harris makes \${:.2f} to \${:.2f} per podcast'.format(
    credible_region[0], 
    credible_region[1]
)))
# Out:
#                   m             b         noise       sam_hat
# count  24500.000000  24500.000000  24500.000000  24500.000000
# mean       2.241637    171.824525    608.179044  19029.417338
# std        0.227743    142.991984     64.861260   1891.925869
# min        1.455619   -350.954066    375.607715  11635.352249
# 25%        2.090943     67.724783    562.580551  17746.648670
# 50%        2.258227    162.571172    604.570382  19150.260797
# 75%        2.421845    267.833899    649.717201  20466.286626
# max        3.127541    733.985819    896.705675  25953.557234
# [ 15680.62138035  21863.70010873]
# ### 95% Chance Sam Harris makes \$15680.62 to \$21863.70 per podcast

# %% [markdown]
# Made with <3 Stephen Anthony Rose
